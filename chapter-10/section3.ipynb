# %% [markdown]
# ## 10.3 幻灯片样式调整
#
# 一页幻灯片通常由以下8个部分中的一些或全部所组成：
#
# - 幻动片标题：可以在`frame`环境中，使用`\frametitle{ }`和`\framesubtitle{ }`命令为幻灯片添加标题和副标题。
#
# - 侧边栏：侧边栏由任一侧的所选主题自动生成，主要用于显示演示文稿的目录；
#
# - 导航栏：导航栏也由所选主题自动生成，主要用两个目的，一是，在演示过程中的任何时间点，观众都可以看到演讲内容已经涵盖了多少，还有哪些内容还没有进行；二是，如果需要，演示者可以通过单击相应的链接跳转到特定页；
#
# - 导航符号：每张幻灯片右下角的浅灰色小图标显示了八个默认导航符号。 这些从左到右被称为幻灯片图标、框架图标、小节图标、节图标、演示文稿图标、附录图标、后退和前进图标以及搜索图标。 每个幻灯片、框架、小节和节图标前面都有一个左箭头，后跟一个右箭头。 单击左箭头将引导至上一张幻灯片， 单击向右箭头将引导至下一张幻灯片；
#
# - Logo：Logo一般为幻灯片作者或机构的标志符号，通过导言中的`\logo{}`命令，可以在所有幻灯片页插入文字或图标。
#
# - 背景：每一页幻灯片都有一个背景，由背景画布和主背景组成。背景画布是一个填充整个框架的大矩形，主要背景和幻灯内容在背景画布上填充。
#
# - 幻灯片内容：幻灯片的内容可以是 LaTeX 支持的任何文本、图形，包括上述框架标题和副标题。
#
# - 脚注：类似于LaTeX文章类型的页脚，用于显示演示文稿的一些相关信息；
#
# - 导航符号：每张幻灯片右下角的浅灰色小图标显示了八个默认导航符号。 这些从左到右被称为幻灯片图标、框架图标、小节图标、节图标、演示文稿图标、附录图标、后退和前进图标以及搜索图标。 每个幻灯片、框架、小节和节图标前面都有一个左箭头，后跟一个右箭头。 单击左箭头将引导至上一张幻灯片， 单击向右箭头将引导至下一张幻灯片
#
#
# ### 10.3.1 幻灯片标题的设置
#
# 在`frame`环境中，可以直接使用`begin{frame}{title}{subtitle}`命令为幻灯片添加标题和副标题，也可以使用`\frametitle{ }`和`\framesubtitle{ }`命令分开添加。
#
# 【**例1**】在`frame`环境中，使用`\frametitle{}`和`\framesubtitle{}`命令创建一个带标题和副标题的幻灯片。
# ```tex
# \documentclass{beamer}
# \usefonttheme{professionalfonts}
#
# \begin{document}
#
# \begin{frame}{Parent function}{A short list}
#
# Please check out the following parent function list.
# \begin{enumerate}
# \item $y=x$
# \item $y=|x|$
# \item $y=x^{2}$
# \item $y=x^{3}$
# \item $y=x^{b}$
# \end{enumerate}
#
# \end{frame}
#
# \end{document}
# ```
#
# 【**例2**】在`frame`环境中，使用`\frametitle{}`和`\framesubtitle{}`命令创建一个带标题和副标题的幻灯片。
#
# ```tex
# \documentclass{beamer}
# \usefonttheme{professionalfonts}
#
# \begin{document}
#
# \frame{\frametitle{Parent function}
# \framesubtitle{A short list}
#
# Please check out the following parent function list.
# \begin{enumerate}
# \item $y=x$
# \item $y=|x|$
# \item $y=x^{2}$
# \item $y=x^{3}$
# \item $y=x^{b}$
# \end{enumerate}
#
# }
#
# \end{document}
# ```
#
# ### 10.3.2 侧边栏的设置
#
# 在`frame`环境中，有时为了显示幻灯片的层次，使用侧边栏进行目录索引，可以使用？命令为幻灯片添加脚注。
#
# 【**例3**】使用`Berkeley`主题样式，并将侧边栏显示在右侧。
#
# ```tex
# \PassOptionsToPackage{right}{beamerouterthemesidebar}
# \documentclass{beamer}
# \usetheme{Berkeley}
# \usefonttheme{professionalfonts}
#
# \begin{document}
#
# \begin{frame}
# \frametitle{Parent function}
# \framesubtitle{A short list}
#
# Please check out the following parent function list.
# \begin{enumerate}
# \item $y=x$
# \item $y=|x|$
# \item $y=x^{2}$
# \item $y=x^{3}$
# \item $y=x^{b}$
# \end{enumerate}
#
# \end{frame}
#
# \end{document}
# ```
#
# ### 10.3.3 Logo的设置
#
# Logo一般为幻灯片作者或机构的标志符号，通过导言中的`\logo{}`命令，可以在所有幻灯片页插入文字或图标。
#
# 【**例4**】在`frame`环境中，使用`\logo{}`插入图标作为Logo。
#
# ```tex
# \documentclass{beamer}
#
# \title{LaTeX cookbook}
# \author{Authors}
# \date{\today}
# \logo{
# \includegraphics[width=2cm]{LaTeX-Cookbook.png}
# }
#
# \begin{document}
#
# \begin{frame}
#     \titlepage
# \end{frame}
#
# \begin{frame}{Parent function}{A short list}
# Please check out the following parent function list.
# \begin{enumerate}
# \item $y=x$
# \item $y=|x|$
# \item $y=x^{2}$
# \item $y=x^{3}$
# \item $y=x^{b}$
# \end{enumerate}
# \end{frame}
#
# \end{document}
# ```
#
# 【**例5**】使用`beamer`文档类型创建一个简单的幻灯片，并在幻灯片的右上角插入一个文本形式的logo。
#
# ```tex
# \documentclass{beamer}
# \usefonttheme{professionalfonts}
# \usetheme[height = 12mm]{Rochester}
# \usepackage{textpos}
# \addtobeamertemplate{headline}{}{
# \begin{textblock*}{100mm}(0.8\textwidth, -1cm)
# \Huge\textcolor{white}{\textbf{\LaTeX}}
# \end{textblock*}}
#
# \begin{document}
#
# \begin{frame}
# \frametitle{Parent function}
# \framesubtitle{A short list}
#
# Please check out the following parent function list.
# \begin{enumerate}
# \item $y=x$
# \item $y=|x|$
# \item $y=x^{2}$
# \item $y=x^{3}$
# \item $y=x^{b}$
# \end{enumerate}
#
# \end{frame}
#
# \end{document}
# ```
#
# 在这组代码中，`textpos`宏宝可用于控制文本的位置，将文本形式的logo放在幻灯片的右上角。另外，我们需要指定logo位于幻灯片顶部，并用`textblock`环境生成文本形式的logo。
#
# > 参考LaTeX论坛贴吧[Beamer Logo Position](https://latex.org/forum/viewtopic.php?f=61&t=29136)。
#
#
# ### 10.3.4 背景的设置
#
# 在Beamer中加入背景图片只要把背景重新设置一下，可以使用\setbeamertemplate{background}{\pgfuseimage{name of image}}命令为来设置修改背景图片。
#
#
# ### 10.3.8 脚注的设置
#
# 在`frame`环境中，，可以使用？命令为幻灯片添加脚注，用来显示幻灯片的页码、作者、日期等一些相关信息。

# %% [markdown]
# 【回放】[**10.2 Beamer主题样式与主题颜色**](https://nbviewer.jupyter.org/github/xinychen/latex-cookbook/blob/main/chapter-10/section2.ipynb)
#
# 【继续】[**10.4 编辑文本**](https://nbviewer.jupyter.org/github/xinychen/latex-cookbook/blob/main/chapter-10/section4.ipynb)

# %% [markdown]
# ### License
#
# <div class="alert alert-block alert-danger">
# <b>This work is released under the MIT license.</b>
# </div>
