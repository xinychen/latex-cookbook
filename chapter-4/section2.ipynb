# %% [markdown]
# ## 4.2 常用的运算符号
#
# 在初等数学中，最基本的运算规则是加减乘除。在LaTeX中，加法符号和减法符号就是+和-；而乘除法则不同，乘法符号有两种，第一种是`\times`，对应于符号$\times$，第二种是`\cdot`，对应于符号$\cdot$，除法符号的命令为`\div`。
#
# 【**例1**】书写加减乘除$3+5$、$3-5$、$3\times 5$、$3\cdot 5$和$3\div 5$。
#
# ```tex
# \documentclass[12pt]{article}
# \begin{document}
#
# $$3+5$$        % 加法
# $$3-5$$        % 减法
# $$3\times 5$$  % 乘法
# $$3\cdot 5$$   % 乘法
# $$3\div 5$$    % 除法
#
# \end{document}
# ```
#
# 除了加减乘除这些最为基本的运算符号，还有一些基本数学表达式，例如分式、上标、下标。LaTeX中用于书写分数和分式的基本命令为`\frac{分子}{分母}`，根据场景需要，也可以选用`\dfrac{}{}`和`\tfrac{}{}`。
#
# 【**例2**】书写分数$\frac{3}{5}$与分式$\frac{x}{y}$、$\frac{x+3}{y+5}$。
#
# ```tex
# \documentclass[12pt]{article}
# \begin{document}
#
# $$\frac{3}{5}$$      % 分数
# $$\frac{x}{y}$$      % 分式1
# $$\frac{x+3}{y+5}$$  % 分式2
#
# \end{document}
# ```
#
# 根号的命令为`\sqrt{}`，使用默认设置，生成的表达式为二次方根，如果想要设置为三次方根，则需要调整默认设置，即`\sqrt[3]{}`，以此类推，可以设置四次方根等。
#
# 【**例3**】书写根式$\sqrt{3}$、$\sqrt[3]{5}$、$\sqrt{x+y}$、$\sqrt{x^{3}+y^{5}}$、$\sqrt{1+\sqrt{x}}$。
#
# ```tex
# \documentclass[12pt]{article}
# \begin{document}
#
# $$\sqrt{3}$$
# $$\sqrt[3]{5}$$
# $$\sqrt{x+y}$$
# $$\sqrt{x^{3}+y^{5}}$$
# $$\sqrt{1+\sqrt{x}}$$
#
# \end{document}
# ```
#
# 【**例4**】书写分式和根式组合的表达式$\frac{\sqrt{x+3}}{\sqrt{y+5}}$。
#
# ```tex
# \documentcl
# ```
#
# 上标和下标在各类数学表达式中是非常常见的。
#
# 【**例4**】书写带上标的$x^{3}$、$x^{5}$、$x^{x+5}$和$x^{x^{3}+5}$。
#
# ```tex
# \documentclass[12pt]{article}
# \begin{document}
#
# $$x^{3}$$
# $$x^{5}$$
# $$x^{x+5}$$
# $$x^{x^{3}+5}$$
#
# \end{document}
# ```
#
# 【**例5**】书写带下标的$x_{3}$、$x_{5}$、$x_{x+5}$、$x_{x_{3}+5}$和$x_{1},x_{2},\ldots,x_{n}$。
#
# ```tex
# \documentclass[12pt]{article}
# \begin{document}
#
# $$x_{3}$$
# $$x_{5}$$
# $$x_{x+5}$$
# $$x_{x_{3}+5}$$
# $$x_{1},x_{2},\ldots,x_{n}$$
#
# \end{document}
# ```

# %% [markdown]
# 【回放】[**4.1 基本介绍**](https://nbviewer.jupyter.org/github/xinychen/latex-cookbook/blob/main/chapter-4/section1.ipynb)
#
# 【继续】[**4.3 xxxx**](https://nbviewer.jupyter.org/github/xinychen/latex-cookbook/blob/main/chapter-4/section3.ipynb)

# %% [markdown]
# ### License
#
# <div class="alert alert-block alert-danger">
# <b>This work is released under the MIT license.</b>
# </div>
